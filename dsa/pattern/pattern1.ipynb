# %%
n=int(input())
for i in range(n):
  for j in range(1,n+1):
    print(j,end="")
  print()
# Out:
# 4
# 1234
# 1234
# 1234
# 1234

# %%
n=4
for i in range(n):
  for j in range(n):
    print(n,end="")
  print()
# Out:
# 4444
# 4444
# 4444
# 4444

# %%
''''
1
22
333
4444
55555
'''
n=5
for i in range(1,n+1):
  k=i
  for j in range(i):
    print(k,end='')
  print()
  k+=1
# Out:
# 1
# 22
# 333
# 4444
# 55555

# %%
# 1
# 23
# 345
# 4567

for i in range(1,n+1):
  k=i
  for j in range(i):
    print(k,end='')
    k+=1
  print()
# Out:
# 1
# 23
# 345
# 4567
# 56789

# %%
# 1
# 21
# 321
# 4321
# 54321

for i in range(1,n+1):
  k=i
  for j in range(i):
    print(k,end='')
    k-=1
  print()
# Out:
# 1
# 21
# 321
# 4321
# 54321

# %%
# 1234
# 1234
# 1234
# 1234

for i in range(n):
  for j in range(n):
    print(j+1,end="")
  print()
# Out:
# 12345
# 12345
# 12345
# 12345
# 12345
